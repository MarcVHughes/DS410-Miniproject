# %%
import pandas as pd
import numpy as np

# %%
january_august2019 = pd.read_csv('January_August.csv')
september_march2020 = pd.read_csv('September_March2020.csv')

# %%
january_august2019.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0      1             1            2                F9   N216FR
# 1      1             1            2                F9   N344FR
# 2      1             1            2                F9   N211FR
# 3      1             1            2                F9   N223FR
# 4      1             1            2                AS   N613AS
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN      ORIGIN_CITY_NAME  \
# 0                292              11292    DEN            Denver, CO
# 1                488              11292    DEN            Denver, CO
# 2               1748              11109    COS  Colorado Springs, CO
# 3                680              11292    DEN            Denver, CO
# 4                128              11630    FAI         Fairbanks, AK
#
#    DEST_AIRPORT_ID  ... CANCELLED CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  \
# 0            15304  ...         0              206                  235
# ...
