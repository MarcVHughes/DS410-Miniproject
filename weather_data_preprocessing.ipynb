# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Weather Data Preprocessing
# For feature documentation refer to 'GHCND_documentation.pdf'

# %%
weather2019 = pd.read_csv('raw_data/airport_weather_2019.csv')
weather2020 = pd.read_csv('raw_data/airport_weather_2020.csv')

# %%
weather2019.head(2)
# Out:
#        STATION                                               NAME      DATE  \
# 0  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...  1/1/2019
# 1  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...  1/2/2019
#
#    AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  ...  WT08  WT09  WESD  WT10  \
# 0  4.70   NaN  0.14   0.0   0.0  64.0  66.0  ...   NaN   NaN   NaN   NaN
# 1  4.92   NaN  0.57   0.0   0.0  56.0  59.0  ...   1.0   NaN   NaN   NaN
#
#    PSUN  TSUN  SN32  SX32  TOBS  WT11
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
#
# [2 rows x 32 columns]

# %% [markdown]
# #### Selecting only the relevant features

# %%
weather2019 = weather2019[['NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX']]
weather2019
# Out:
#                                                     NAME        DATE   AWND  \
# 0      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/1/2019   4.70
# 1      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/2/2019   4.92
# 2      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/3/2019   5.37
# 3      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/4/2019  12.08
# 4      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/5/2019  13.42
# ...                                                  ...         ...    ...
# 38670                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-27   6.04
# 38671                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-28   5.37
# 38672                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-29   7.61
# 38673                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-30   5.82
# 38674                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-31   3.58
#
#        PRCP  SNOW  SNWD  TAVG  TMAX
# ...

# %%
weather2020.head(2)
# Out:
#                                    NAME        DATE  AWND  PRCP  SNOW  SNWD  \
# 0  FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-01  2.91   0.0   0.0   0.0
# 1  FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-02  2.68   0.0   0.0   0.0
#
#    TAVG  TMAX
# 0  48.0  60.0
# 1  48.0  56.0

# %%
weather2020 = weather2020[['NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'SNWD', 'TAVG', 'TMAX']]
weather2020
# Out:
#                                         NAME        DATE   AWND  PRCP  SNOW  \
# 0       FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-01   2.91  0.00   0.0
# 1       FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-02   2.68  0.00   0.0
# 2       FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-03   3.80  0.00   0.0
# 3       FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-04   5.82  0.00   0.0
# 4       FRESNO YOSEMITE INTERNATIONAL, CA US  2020-01-05   6.49  0.00   0.0
# ...                                      ...         ...    ...   ...   ...
# 7546  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  2020-03-27   3.58  0.21   NaN
# 7547  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  2020-03-28   6.93  1.29   NaN
# 7548  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  2020-03-29  16.55  0.02   NaN
# 7549  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  2020-03-30  13.42  0.00   NaN
# 7550  PITTSBURGH ALLEGHENY CO AIRPORT, PA US  2020-03-31   3.80  0.06   NaN
#
#       SNWD  TAVG  TMAX
# 0      0.0  48.0  60.0
# ...
